# %% [markdown]
# # Assignment

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# # 1. Count of one categorical feature

# %%
df['Foundation']
# Out:
# 0        PConc
# 1       CBlock
# 2        PConc
# 3       BrkTil
# 4        PConc
#          ...
# 1455     PConc
# 1456    CBlock
# 1457     Stone
# 1458    CBlock
# 1459    CBlock
# Name: Foundation, Length: 1460, dtype: object

# %%
sns.countplot(data=df, x='Foundation')
# Out:
# <Axes: xlabel='Foundation', ylabel='count'>

# %%
## ingin mengurutkan nilainya
foundation_count = df.groupby(['Foundation'],as_index=False).size()
foundation_count = foundation_count.sort_values(['size'],ascending=False)

# %%
foundation_count
# Out:
#   Foundation  size
# 2      PConc   647
# 1     CBlock   634
# 0     BrkTil   146
# 3       Slab    24
# 4      Stone     6
# 5       Wood     3

# %%
sns.barplot(x=foundation_count['Foundation'],
            y=foundation_count['size'])
# Out:
# <Axes: xlabel='Foundation', ylabel='size'>

# %% [markdown]
# # 2. Distribution of one continuous feature

# %%
df['MSSubClass']
# Out:
# 0       60
# 1       20
# 2       60
# 3       70
# 4       60
#         ..
# 1455    60
# 1456    20
# 1457    70
# 1458    20
# 1459    20
# Name: MSSubClass, Length: 1460, dtype: int64

# %%
sns.displot(x=df['MSSubClass'], kde=True, color='Red')

# Add labels and title to the plot
plt.xlabel('The Building Class')
plt.ylabel('Count')
plt.title('Distribution of The Building Class')
# Out:
# Text(0.5, 1.0, 'Distribution of The Building Class')

# %% [markdown]
# # 3. Categorical-continuous

# %%
df[['Functional','SalePrice']]
# Out:
#      Functional  SalePrice
# 0           Typ     208500
# 1           Typ     181500
# 2           Typ     223500
# 3           Typ     140000
# 4           Typ     250000
# ...         ...        ...
# 1455        Typ     175000
# 1456       Min1     210000
# 1457        Typ     266500
# 1458        Typ     142125
# 1459        Typ     147500
#
# [1460 rows x 2 columns]

# %%
sns.boxplot(x=df['Functional'],
            y=df['SalePrice'])

## labels and title to the plot
plt.xlabel('Home Functionality Rating')
plt.ylabel('Sale Price')
plt.title('Relationship Between Home Functionality Rating and Sale Price of The Property')
# Out:
# Text(0.5, 1.0, 'Relationship Between Home Functionality Rating and Sale Price of The Property')

# %% [markdown]
# # 4. Continuous-continuous

# %%
## Cara 1
sns.scatterplot(x=df['YearBuilt'],y=df['SalePrice'])
# Out:
# <Axes: xlabel='YearBuilt', ylabel='SalePrice'>

# %%
## cara 2
sns.lmplot(x='YearBuilt', y='SalePrice', data=df, scatter_kws={'color': 'Red'}, line_kws={'color': 'green'})

## labels and title to the plot
plt.xlabel('Year Built')
plt.ylabel('Sale Price')
plt.title('Relationship Between Year Built and The Sale Price of the Property')
# Out:
# Text(0.5, 1.0, 'Relationship Between Year Built and The Sale Price of the Property')

# %% [markdown]
# **THANK YOU**
